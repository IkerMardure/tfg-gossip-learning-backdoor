# %% [markdown]
# ## Draw toplogies from generated YAML files

# %%
# Import and add project root to path
import sys
from pathlib import Path

project_root = Path.cwd().parent if "visualization" in str(Path.cwd()) else Path.cwd()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from utils.topology_visualization import visualize_topology_from_yaml
# Out:
# Running cells with '.venv-1 (3.10.11) (Python 3.10.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Iker/unibertsitatea/praktikak/GLow_TFG/.venv-1/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# Generate topology graph
output = visualize_topology_from_yaml(
    yaml_path=yaml_file,
    output_path="visualization",  # Saves to visualization/
    image_format="png",
    layout="spring",
    seed=42,
    show_labels=show_node_numbers
)
print(f"✓ Topology graph saved: {output}")

# %%
# Configuration: Edit these parameters
yaml_file = "conf/topologies/ring30+5.yaml"  # Path to topology YAML
show_node_numbers = True                      # Set to False to hide node labels
